# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
nvt_temp_path = "/home/shpark/prj-mlcv/lib/bioemu/opes/data/1FME/temperature.xvg"
with open(nvt_temp_path) as f:
    lines = [line for line in f if not line.startswith(('#', '@'))]

from io import StringIO
npt_temp_data = pd.read_csv(StringIO("".join(lines)), delim_whitespace=True, header=None)

plt.figure(figsize=(10, 5))
plt.plot(npt_temp_data[0], npt_temp_data[1])
plt.axhline(y=325, color="blue", linestyle='--', label='Target Temperature')
plt.xlabel("Time (ps)")
plt.ylabel("Temperature (K)")
# Out:
# /tmp/ipykernel_3949092/3776886920.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   npt_temp_data = pd.read_csv(StringIO("".join(lines)), delim_whitespace=True, header=None)
# Text(0, 0.5, 'Temperature (K)')

# %%
nvt_temp_path = "/home/shpark/prj-mlcv/lib/bioemu/opes/data/1FME/pressure.xvg"
with open(nvt_temp_path) as f:
    lines = [line for line in f if not line.startswith(('#', '@'))]

npt_temp_data = pd.read_csv(StringIO("".join(lines)), delim_whitespace=True, header=None)

plt.figure(figsize=(10, 5))
plt.plot(npt_temp_data[0], npt_temp_data[1])
plt.xlabel("Time (ps)")
# plt.ylim(-800, 600)
plt.ylabel("Pressure")
# Out:
# /tmp/ipykernel_3949092/688006814.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   npt_temp_data = pd.read_csv(StringIO("".join(lines)), delim_whitespace=True, header=None)
# Text(0, 0.5, 'Pressure')

# %%
nvt_temp_path = "/home/shpark/prj-mlcv/lib/bioemu/opes/data/1FME/density.xvg"
with open(nvt_temp_path) as f:
    lines = [line for line in f if not line.startswith(('#', '@'))]

npt_temp_data = pd.read_csv(StringIO("".join(lines)), delim_whitespace=True, header=None)

plt.figure(figsize=(10, 5))
plt.plot(npt_temp_data[0], npt_temp_data[1])
plt.xlabel("Time (ps)")
plt.ylim(900, 1040)
plt.ylabel("Density")
# Out:
# /tmp/ipykernel_3949092/2459361592.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   npt_temp_data = pd.read_csv(StringIO("".join(lines)), delim_whitespace=True, header=None)
# Text(0, 0.5, 'Density')

# %%
# xtc_path = "/home/shpark/prj-mlcv/lib/bioemu/opes/simulations/cln025/ours/0907_065813/analysis/0_tc.xtc"
xtc_path = "/home/shpark/prj-mlcv/lib/bioemu/opes/simulations/1fme/tica/debug/0.xtc"
pdb_path = "./1FME/folded.gro"
traj = md.load_xtc(xtc_path, pdb_path)
traj.center_coordinates()

import nglview as nv
view = nv.show_mdtraj(traj[::100])
view.add_representation("licorice",selection="protein")
view
# Out:
# NGLWidget()
